# %%
from bagpy import bagreader
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.

# %%
b = bagreader('/home/ivory/CyverseData/ProjectSparkle/catvehicle_n_1_update_rate_100.0_max_update_rate_100.0_time_step_0.01_logtime_20.0_2020-03-04-21-11-30.bag')
# Out:
# [INFO]  Data folder /home/ivory/CyverseData/ProjectSparkle/catvehicle_n_1_update_rate_100.0_max_update_rate_100.0_time_step_0.01_logtime_20.0_2020-03-04-21-11-30 already exists. Not creating.

# %%
print(b.__doc__)
# Out:
#     `bagreader` class provides API to read rosbag files in an effective easy manner with significant hassle.
#     This class is reimplementation of its MATLAB equivalent that can be found at https://github.com/jmscslgroup/ROSBagReader
#
#     Parameters
#     ----------------
#     bagfile: `string`
#         Bagreader constructor takes name of a bag file as an  argument. name of the bag file can be provided as the full  qualified path, relative path or just the file name.
#
#     Attributes
#     --------------
#     bagfile: `string`
#         Full path of the bag  file, e.g `/home/ece446/2019-08-21-22-00-00.bag`
#     filename: `string`
#         Name of the bag file, e.g. `2019-08-21-22-00-00.bag`
#     dir: `string`
#         Directory where bag file is located
#     reader: `rosbag.Bag`
#         rosbag.Bag object that
#
#     topic: `pandas dataframe`
#         stores the available topic from bag file being read as a table
#     n_messages: `integer`
# ...

# %%
b.topic_table
# Out:
#                                                Topics  \
# 0                                              /clock
# 1                                 /gazebo/link_states
# 2                                /gazebo/model_states
# 3                      /gazebo/parameter_descriptions
# 4                           /gazebo/parameter_updates
# 5                                      /magna/cmd_vel
# 6                                 /magna/cmd_vel_safe
# 7         /magna/distanceEstimatorSteeringBased/Xdist
# 8         /magna/distanceEstimatorSteeringBased/Ydist
# 9         /magna/distanceEstimatorSteeringBased/angle
# 10         /magna/distanceEstimatorSteeringBased/dist
# 11                          /magna/front_laser_points
# 12  /magna/front_left_steering_position_controller...
# 13  /magna/front_right_steering_position_controlle...
# 14          /magna/joint1_velocity_controller/command
# 15          /magna/joint2_velocity_controller/command
# ...

# %%
b.animate_laser()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-8a4be557b76c> in <module>
# ----> 1 b.animate_laser()
#
# ~/anaconda3/envs/dbn/lib/python3.7/site-packages/bagpy-0.1-py3.7.egg/bagpy/bagreader.py in animate_laser(self)
#     228
#     229     def animate_laser(self):
# --> 230         raise NotImplementedError("To be implemented")
#     231
#     232     def animate_pointcloud(self):
#
# NotImplementedError: To be implemented

# %%
b.bagfile
# Out:
# '/home/ivory/CyverseData/ProjectSparkle/catvehicle_n_1_update_rate_100.0_max_update_rate_100.0_time_step_0.01_logtime_20.0_2020-03-04-21-11-30.bag'

# %%
b.clock_data()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-02e5d4fc86fd> in <module>
# ----> 1 b.clock_data()
#
# ~/anaconda3/envs/dbn/lib/python3.7/site-packages/bagpy-0.1-py3.7.egg/bagpy/bagreader.py in clock_data(self, **kwargs)
#     207
#     208     def  clock_data(self, **kwargs):
# --> 209         raise NotImplementedError("To be implemented")
#     210
#     211     def pointcloud_data(self, **kwargs):
#
# NotImplementedError: To be implemented

# %%
b.compressed_images()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-8-a4db3118f94e> in <module>
# ----> 1 b.compressed_images()
#
# ~/anaconda3/envs/dbn/lib/python3.7/site-packages/bagpy-0.1-py3.7.egg/bagpy/bagreader.py in compressed_images(self, **kwargs)
#     198
#     199     def compressed_images(self, **kwargs):
# --> 200         raise NotImplementedError("To be implemented")
#     201
#     202     def odometry_data(self, **kwargs):
#
# NotImplementedError: To be implemented

# %%
b.datafolder
# Out:
# '/home/ivory/CyverseData/ProjectSparkle/catvehicle_n_1_update_rate_100.0_max_update_rate_100.0_time_step_0.01_logtime_20.0_2020-03-04-21-11-30'

# %%
b.dir
# Out:
# '/home/ivory/CyverseData/ProjectSparkle'

# %%
b.end_time
# Out:
# 58.78

# %%
b.filename
# Out:
# '/catvehicle_n_1_update_rate_100.0_max_update_rate_100.0_time_step_0.01_logtime_20.0_2020-03-04-21-11-30.bag'

# %%
b.frequency
# Out:
# [100.0000000000199,
#  None,
#  100.0000000000199,
#  None,
#  None,
#  9.999999999999858,
#  49.999999999992184,
#  25.000000000000533,
#  25.000000000000533,
#  25.000000000000533,
#  25.000000000000533,
#  50.00000000000995,
#  100.0000000000199,
#  100.0000000000199,
#  100.0000000000199,
#  100.0000000000199,
#  None,
#  None,
#  9.999999999999858,
#  100.0000000000199,
#  100.0000000000199,
#  None,
#  None,
#  50.00000000000995,
#  None,
#  None]

# %%
L = b.laser_data()

# %%
L
# Out:
# [[header:
#     seq: 426
#     stamp:
#       secs: 39
#       nsecs:  30000000
#     frame_id: "magna/front_laser_link"
#   angle_min: -1.5700000524520874
#   angle_max: 1.5700000524520874
#   angle_increment: 0.017541900277137756
#   time_increment: 0.0
#   scan_time: 0.0
#   range_min: 1.5
#   range_max: 80.0
# ...

# %%
L[0][0]
# Out:
# header:
#   seq: 426
#   stamp:
#     secs: 39
#     nsecs:  30000000
#   frame_id: "magna/front_laser_link"
# angle_min: -1.5700000524520874
# angle_max: 1.5700000524520874
# angle_increment: 0.017541900277137756
# time_increment: 0.0
# scan_time: 0.0
# range_min: 1.5
# range_max: 80.0
# ...
